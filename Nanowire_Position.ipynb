# %%
import pathlib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_dir = pathlib.Path(r'C:\Users\dixon\Desktop\Nanowire_Code\Nanowire_position')
validation_dir=pathlib.Path(r'C:\Users\dixon\Desktop\Nanowire_Code\Nanowire_position')

image_train= tf.keras.utils.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='categorical',
    #class_names=['left', 'no', 'right'],
    color_mode='grayscale',
    batch_size=8,
    image_size=(540,960),
    seed=128,
    validation_split=0.1,
    subset='training',
    )

image_validation= tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    labels='inferred',
    label_mode='categorical',
    #class_names=['left', 'no', 'right'],
    color_mode='grayscale',
    batch_size=8,
    image_size=(540,960),
    seed=128,
    validation_split=0.5,
    subset='validation',
    )


'''
datagen = ImageDataGenerator(rescale=1.0/255)
image_train = datagen.flow_from_directory(
    data_dir,
    target_size=(1080,1920),
    batch_size=6,
    color_mode="grayscale",
    class_mode="sparse",
    shuffle=True,
    subset="training",
    seed=123,
)

vali_datagen = ImageDataGenerator(rescale=1.0/255)

image_validation = vali_datagen.flow_from_directory(
    validation_dir,
    target_size=(1880,1000),
    batch_size=6,
    color_mode="grayscale",
    class_mode="sparse",
    shuffle=False,
    subset="validation",
    seed=123,
)
'''

model = tf.keras.Sequential()
model.add (tf.keras.Input (shape=(540,960)))
#model.add (tf.keras.layers.Reshape ((540,960))) 
model.add (tf.keras.layers.BatchNormalization())
model.add (tf.keras.layers.Bidirectional (tf.keras.layers.GRU (128, return_sequences=True)))
model.add (tf.keras.layers.GRU (64))
model.add (tf.keras.layers.Dense(32,activation='relu'))
model.add (tf.keras.layers.Dense(12,activation='relu'))
model.add (tf.keras.layers.Dense(3))

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    3.5e-3,
    decay_steps=24,
    decay_rate=0.97,
    staircase=True)

loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True)
opt=tf.keras.optimizers.Adadelta(learning_rate=lr_schedule)

model.compile (loss=loss, optimizer=opt, metrics=["accuracy"])
model.summary ()

model.fit (image_train, batch_size=12, epochs=10, verbose=2)
model.evaluate (image_validation, batch_size=12, verbose=2)
# Out:
# Found 209 files belonging to 3 classes.
# Using 189 files for training.
# Found 209 files belonging to 3 classes.
# Using 104 files for validation.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  batch_normalization_4 (Batc  (None, 540, 960)         3840
#  hNormalization)
#
#  bidirectional_4 (Bidirectio  (None, 540, 256)         837120
#  nal)
#
#  gru_9 (GRU)                 (None, 64)                61824
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 12)                396
#
#  dense_14 (Dense)            (None, 3)                 39
#
# ...
# Total params: 905,299
# Trainable params: 903,379
# Non-trainable params: 1,920
# _________________________________________________________________
# Epoch 1/10
# 24/24 - 25s - loss: 1.0939 - accuracy: 0.3228 - 25s/epoch - 1s/step
# Epoch 2/10
# ...

# %%
img_0_dir0=pathlib.Path(r'C:\Users\dixon\Desktop\up\WIN_20220121_18_28_23_Pro.JPG')
img_0_dir1=pathlib.Path(r'C:\Users\dixon\Desktop\up\WIN_20220121_18_37_10_Pro.JPG')
img_0_dir2=pathlib.Path(r'C:\Users\dixon\Desktop\up\WIN_20220121_18_39_03_Pro.JPG')
img_0_dir3=pathlib.Path(r'C:\Users\dixon\Desktop\up\WIN_20220121_18_39_58_Pro.JPG')
img_0_dir4=pathlib.Path(r'C:\Users\dixon\Desktop\up\WIN_20220121_18_40_27_Pro.JPG')

img_1_dir0=pathlib.Path(r'C:\Users\dixon\Desktop\center\WIN_20220121_18_30_38_Pro.JPG')
img_1_dir1=pathlib.Path(r'C:\Users\dixon\Desktop\center\WIN_20220121_18_32_40_Pro.JPG')
img_1_dir2=pathlib.Path(r'C:\Users\dixon\Desktop\center\WIN_20220121_18_35_38_Pro.JPG')
img_1_dir3=pathlib.Path(r'C:\Users\dixon\Desktop\center\WIN_20220121_18_38_49_Pro.JPG')
img_1_dir4=pathlib.Path(r'C:\Users\dixon\Desktop\center\WIN_20220121_18_40_41_Pro.JPG')

img_m1_dir0=pathlib.Path(r'C:\Users\dixon\Desktop\down\WIN_20220121_18_36_23_Pro.JPG')
img_m1_dir1=pathlib.Path(r'C:\Users\dixon\Desktop\down\WIN_20220121_18_35_15_Pro.JPG')
img_m1_dir2=pathlib.Path(r'C:\Users\dixon\Desktop\down\WIN_20220121_18_30_03_Pro.JPG')
img_m1_dir3=pathlib.Path(r'C:\Users\dixon\Desktop\down\WIN_20220121_18_33_00_Pro.JPG')
img_m1_dir4=pathlib.Path(r'C:\Users\dixon\Desktop\down\WIN_20220121_18_40_12_Pro.JPG')

for i in (img_0_dir0,img_0_dir1,img_0_dir2,img_0_dir3,img_0_dir4,
          img_1_dir0,img_1_dir1,img_1_dir2,img_1_dir3,img_1_dir4,
          img_m1_dir0,img_m1_dir1,img_m1_dir2,img_m1_dir3,img_m1_dir4):
    
    image = tf.keras.preprocessing.image.load_img(i,grayscale=True)
    input_arr = tf.keras.preprocessing.image.img_to_array(image)
    input_arr = np.array([input_arr])
    predictions = model.predict(input_arr)
    answer=np.argmax(predictions,axis=1)
    print (answer)
